# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_c3_r1_virus = pd.read_csv("/hdd/code/CassBERT/trained_models/protein_final/model_k5_c3_bp100/P27-4C-R1-Trimmed/virus_1.csv",
                          header=None)
df_c3_r2_virus = pd.read_csv("/hdd/code/CassBERT/trained_models/protein_final/model_k5_c3_bp100/P27-4C-R2-Trimmed/virus_1.csv",
                          header=None)

df_c2_r1_virus = pd.read_csv("/hdd/code/CassBERT/trained_models/protein_final/model_k5_c2_bp100/P27-4C-R1-Trimmed/virus_0.csv",
                          header=None)
df_c2_r2_virus = pd.read_csv("/hdd/code/CassBERT/trained_models/protein_final/model_k5_c2_bp100/P27-4C-R2-Trimmed/virus_2.csv",
                          header=None)

# %%
n, bins, patches = plt.hist(df_c2_r2_virus[1], bins=10, edgecolor='black', rwidth=0.9)
for i in range(len(patches)):
    plt.text(patches[i].get_x() + patches[i].get_width() / 2,
             n[i],
             str(int(n[i])),
             ha='center',
             va='bottom')
plt.xlabel('Predicted Probabilities')
plt.ylabel('Frequency')
plt.show()
